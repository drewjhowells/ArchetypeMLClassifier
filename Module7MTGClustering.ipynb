# %% [markdown]
# # MTG Archetype Discovery and Clustering

# %% [markdown]
# ## Imports

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pathlib import Path
from datetime import datetime
from docx import Document
from docx.shared import Inches

import hdbscan
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.linear_model import LogisticRegression
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Load and Normalize Deck Data

# %%
DATA_PATH = Path("M7_Decks/mtg/modern/mtg_modern.json")

# Define lands to skip during analysis to avoid clustering issues
basic_lands = ["Plains", "Island", "Swamp", "Mountain", "Forest", "Wastes"]
snow_lands = ["Snow-Covered Plains", "Snow-Covered Island", "Snow-Covered Swamp",
              "Snow-Covered Mountain", "Snow-Covered Forest", "Snow-Covered Wastes"]
fetch_lands = ["Flooded Strand", "Polluted Delta", "Bloodstained Mire", "Windswept Heath",
    "Wooded Foothills", "Scalding Tarn", "Marsh Flats", "Arid Mesa",
    "Verdant Catacombs", "Misty Rainforest", "Prismatic Vista"]
lands_to_skip = set([normalize_card_name(name) for name in basic_lands + snow_lands + fetch_lands])

with open(DATA_PATH, "r") as f:
    raw_decks = json.load(f)

def normalize_card_name(name):
    name = name.lower()
    if "//" in name:
        name = name.split("//")[0].strip()
    
    return (
        name.replace(" ", "_")
            .replace(",", "")
            .replace("'", "")
    )

def deck_to_text(deck, include_sideboard=False):
    cards = []
    for entry in deck["maindeck"]:
        token = normalize_card_name(entry["card"])
        if token not in lands_to_skip:
            cards.extend([token] * entry["quantity"])

    if include_sideboard:
        for entry in deck["sideboard"]:
            token = normalize_card_name(entry["card"])
            if token not in lands_to_skip:
                cards.extend([token] * entry["quantity"])

    return " ".join(cards)

rows = []
for deck in raw_decks:
    rows.append({
        "date": datetime.fromisoformat(deck["date"]),
        "deck_text": deck_to_text(deck),
        "record": deck.get("record"),
        "url": deck.get("url")
    })

df = pd.DataFrame(rows).sort_values("date").reset_index(drop=True)
df.head()
# Out:
#         date                                          deck_text record  \
# 0 2025-09-21  ral_monsoon_mage ral_monsoon_mage ral_monsoon_...  4-1-2
# 1 2025-09-21  pinnacle_monk pinnacle_monk pinnacle_monk pinn...  3-2-1
# 2 2025-09-21  ral_monsoon_mage ral_monsoon_mage ral_monsoon_...  0-3-0
# 3 2025-09-21  overlord_of_the_balemurk overlord_of_the_balem...  1-1-2
# 4 2025-09-21  pinnacle_monk pinnacle_monk pinnacle_monk pinn...  0-4-0
#
#                                                  url
# 0  https://melee.gg/Decklist/View/0e1bee94-da43-4...
# 1  https://melee.gg/Decklist/View/f05db1ce-f2ad-4...
# 2  https://melee.gg/Decklist/View/ee7fd52a-f73c-4...
# 3  https://melee.gg/Decklist/View/ed501546-9289-4...
# 4  https://melee.gg/Decklist/View/bb00eb8a-dbed-4...

# %% [markdown]
# ## Split into Train and Test Sets

# %%
# Split into Train and Test Sets ranther than Temporal Split
split_index = int(0.8 * len(df))
df_train = df.iloc[:split_index].reset_index(drop=True)
df_test = df.iloc[split_index:].reset_index(drop=True)
print(f"Training set size: {len(df_train)} decks")
print(f"Test set size: {len(df_test)} decks")
# Out:
# Training set size: 10126 decks
# Test set size: 2532 decks

# %% [markdown]
# ## Vectorization & Dimensionality Reduction

# %%
vectorizer = TfidfVectorizer(token_pattern=r"[^ ]+", min_df=2, max_df=0.9)
X_train_tfidf = vectorizer.fit_transform(df_train["deck_text"])
X_test_tfidf = vectorizer.transform(df_test["deck_text"])

svd = TruncatedSVD(n_components=100, random_state=42)
X_train_reduced = normalize(svd.fit_transform(X_train_tfidf))
X_test_reduced  = normalize(svd.transform(X_test_tfidf))

# %% [markdown]
# ## Clustering

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=15)
df_train["cluster"] = clusterer.fit_predict(X_train_reduced)

feature_names = vectorizer.get_feature_names_out()

def top_cards_for_cluster(cluster_label, top_n=10):
    idx = df_train["cluster"] == cluster_label
    cluster_tfidf = X_train_tfidf[idx].mean(axis=0)
    cluster_tfidf = np.asarray(cluster_tfidf).flatten()

    top_indices = cluster_tfidf.argsort()[::-1][:top_n]
    return [(feature_names[i], cluster_tfidf[i]) for i in top_indices]

for cluster_label in sorted(df_train["cluster"].unique()):
    if cluster_label == -1:
        continue  # Skip noise
    print(f"Cluster {cluster_label}:")
    for card, score in top_cards_for_cluster(cluster_label):
        print(f"  {card}: {score:.4f}")
    print()
# Out:
# Cluster 0:
#   irencrag_feat: 0.3174
#   pinnacle_monk: 0.3065
#   stormscale_scion: 0.3011
#   shatterskull_smashing: 0.2888
#   bitter_reunion: 0.2753
#   sundering_eruption: 0.2751
#   strike_it_rich: 0.2383
#   pyretic_ritual: 0.2137
#   desperate_ritual: 0.2133
#   manamorphose: 0.2054
#
# Cluster 1:
#   ziatoras_proving_ground: 0.0000
#   goblin_matron: 0.0000
#   glasspool_mimic: 0.0000
#   glasswing_grace: 0.0000
#   glimmervoid: 0.0000
#   glimpse_of_tomorrow: 0.0000
#   glimpse_the_impossible: 0.0000
#   glimpse_the_unthinkable: 0.0000
#   glistener_elf: 0.0000
#   gloomlake_verge: 0.0000
#
# Cluster 2:
#   disrupting_shoal: 0.2935
#   lotus_bloom: 0.2933
#   sea_gate_restoration: 0.2925
#   suppression_ray: 0.2920
#   tameshi_reality_architect: 0.2901
#   whir_of_invention: 0.2900
#   goblin_charbelcher: 0.2888
#   hydroelectric_specimen: 0.2761
#   jwari_disruption: 0.2597
#   sink_into_stupor: 0.1785
#
# Cluster 3:
#   lava_spike: 0.2957
#   goblin_guide: 0.2955
#   skewer_the_critics: 0.2762
#   boltwave: 0.2646
#   searing_blaze: 0.2597
#   boros_charm: 0.2501
#   rift_bolt: 0.2189
#   skullcrack: 0.2080
#   sunbaked_canyon: 0.1713
#   monastery_swiftspear: 0.1481
#
# Cluster 4:
#   archive_trap: 0.3428
#   ruin_crab: 0.3428
#   hedron_crab: 0.3423
#   fractured_sanity: 0.3405
#   drown_in_the_loch: 0.2821
#   surgical_extraction: 0.2694
#   field_of_ruin: 0.2585
#   tashas_hideous_laughter: 0.2492
#   visions_of_beyond: 0.2002
#   fatal_push: 0.1774
#
# Cluster 5:
#   heroes_hangout: 0.3773
#   wrenns_resolve: 0.3186
#   reckless_impulse: 0.3186
#   ral_monsoon_mage: 0.3174
#   ruby_medallion: 0.3124
#   pyretic_ritual: 0.3108
#   desperate_ritual: 0.3102
#   manamorphose: 0.3092
#   past_in_flames: 0.2374
#   wish: 0.1720
#
# Cluster 6:
#   ral_monsoon_mage: 0.3321
#   reckless_impulse: 0.3313
#   wrenns_resolve: 0.3306
#   ruby_medallion: 0.3269
#   pyretic_ritual: 0.3252
#   desperate_ritual: 0.3246
#   manamorphose: 0.3235
#   past_in_flames: 0.2464
#   glimpse_the_impossible: 0.1956
#   wish: 0.1707
#
# Cluster 7:
#   wrenns_resolve: 0.3320
#   reckless_impulse: 0.3320
#   ral_monsoon_mage: 0.3308
#   ruby_medallion: 0.3256
#   pyretic_ritual: 0.3239
#   desperate_ritual: 0.3233
#   manamorphose: 0.3222
#   past_in_flames: 0.2474
#   heroes_hangout: 0.1919
#   wish: 0.1684
#
# Cluster 8:
#   allosaurus_rider: 0.3578
#   neoform: 0.3561
#   eldritch_evolution: 0.3561
#   planar_genesis: 0.3538
#   pact_of_negation: 0.3477
#   veil_of_summer: 0.3338
#   summoners_pact: 0.2093
#   disciple_of_freyalise: 0.1895
#   ghalta_stampede_tyrant: 0.1786
#   hedge_maze: 0.1709
#
# Cluster 9:
#   allosaurus_rider: 0.3552
#   eldritch_evolution: 0.3535
#   neoform: 0.3535
#   planar_genesis: 0.3513
#   pact_of_negation: 0.3304
#   veil_of_summer: 0.3148
#   disciple_of_freyalise: 0.2113
#   summoners_pact: 0.2078
#   ghalta_stampede_tyrant: 0.2032
#   bridgeworks_battle: 0.1726
#
# Cluster 10:
#   stinkweed_imp: 0.3222
#   creeping_chill: 0.3164
#   golgari_thug: 0.3017
#   arclight_phoenix: 0.2457
#   life_from_the_loam: 0.2218
#   faithless_looting: 0.2207
#   cathartic_reunion: 0.2157
#   artists_talent: 0.1541
#   otherworldly_gaze: 0.1282
#   lava_dart: 0.1223
#
# Cluster 11:
#   puresteel_paladin: 0.3354
#   colossus_hammer: 0.3173
#   stoneforge_mystic: 0.3072
#   leyline_axe: 0.2924
#   battlefield_improvisation: 0.2539
#   ornithopter: 0.1905
#   inkmoth_nexus: 0.1784
#   mox_opal: 0.1635
#   sigardas_aid: 0.1312
#   urzas_saga: 0.1187
#
# Cluster 12:
#   lotus_bloom: 0.2818
#   whir_of_invention: 0.2818
#   disrupting_shoal: 0.2815
#   tameshi_reality_architect: 0.2810
#   sea_gate_restoration: 0.2801
#   fallaji_archaeologist: 0.2798
#   suppression_ray: 0.2785
#   goblin_charbelcher: 0.2775
#   thundertrap_trainer: 0.2699
#   hydroelectric_specimen: 0.2653
#
# Cluster 13:
#   master_of_the_pearl_trident: 0.3101
#   aether_vial: 0.2706
#   silvergill_adept: 0.2490
#   floodpits_drowner: 0.2345
#   lord_of_atlantis: 0.2317
#   vodalian_hexcatcher: 0.2248
#   tide_shaper: 0.2185
#   mutavault: 0.1896
#   tishanas_tidebinder: 0.1742
#   mindspring_merfolk: 0.1615
#
# Cluster 14:
#   might_of_old_krosa: 0.2392
#   scale_up: 0.2270
#   glistener_elf: 0.1777
#   vines_of_vastwood: 0.1366
#   blighted_agent: 0.1348
#   inkmoth_nexus: 0.1310
#   noble_hierarch: 0.1233
#   ignoble_hierarch: 0.1219
#   blossoming_defense: 0.1213
#   cacophony_scamp: 0.1168
#
# Cluster 15:
#   samwise_gamgee: 0.3802
#   cauldron_familiar: 0.3798
#   gilded_goose: 0.3738
#   chord_of_calling: 0.3530
#   birthing_ritual: 0.2781
#   young_wolf: 0.2170
#   viscera_seer: 0.1848
#   carrion_feeder: 0.1769
#   orcish_bowmasters: 0.1570
#   overgrown_tomb: 0.1481
#
# Cluster 16:
#   tameshi_reality_architect: 0.2851
#   disrupting_shoal: 0.2851
#   whir_of_invention: 0.2849
#   lotus_bloom: 0.2849
#   sea_gate_restoration: 0.2842
#   suppression_ray: 0.2836
#   fallaji_archaeologist: 0.2829
#   goblin_charbelcher: 0.2806
#   thundertrap_trainer: 0.2728
#   hydroelectric_specimen: 0.2682
#
# Cluster 17:
#   tameshi_reality_architect: 0.2817
#   disrupting_shoal: 0.2817
#   whir_of_invention: 0.2815
#   lotus_bloom: 0.2815
#   sea_gate_restoration: 0.2808
#   suppression_ray: 0.2802
#   fallaji_archaeologist: 0.2795
#   goblin_charbelcher: 0.2772
#   thundertrap_trainer: 0.2696
#   hydroelectric_specimen: 0.2650
#
# Cluster 18:
#   through_the_breach: 0.3631
#   emrakul_the_aeons_torn: 0.3274
#   talisman_of_creativity: 0.2406
#   ulamog_the_defiler: 0.2103
#   ugins_labyrinth: 0.1970
#   eldrazi_temple: 0.1533
#   kozileks_command: 0.1526
#   nulldrifter: 0.1448
#   yggdrasil_rebirth_engine: 0.1323
#   devourer_of_destiny: 0.1258
#
# Cluster 19:
#   eldrazi_linebreaker: 0.3812
#   it_that_heralds_the_end: 0.3160
#   secluded_courtyard: 0.2746
#   wastescape_battlemage: 0.2540
#   sowing_mycospawn: 0.2380
#   cavern_of_souls: 0.2229
#   thought-knot_seer: 0.2176
#   ugins_labyrinth: 0.2111
#   devourer_of_destiny: 0.2032
#   eldrazi_temple: 0.1976
#
# Cluster 20:
#   street_wraith: 0.3814
#   generous_ent: 0.3384
#   living_end: 0.3249
#   steamcore_scholar: 0.3161
#   shardless_agent: 0.3084
#   overlord_of_the_balemurk: 0.2751
#   endurance: 0.2655
#   curator_of_mysteries: 0.2529
#   subtlety: 0.2214
#   force_of_negation: 0.1739
#
# Cluster 21:
#   ardent_plea: 0.3934
#   curator_of_mysteries: 0.3670
#   street_wraith: 0.3299
#   generous_ent: 0.3105
#   living_end: 0.2810
#   shardless_agent: 0.2755
#   waker_of_waves: 0.2690
#   endurance: 0.2366
#   striped_riverwinder: 0.2049
#   subtlety: 0.1977
#
# Cluster 22:
#   agathas_soul_cauldron: 0.3772
#   delighted_halfling: 0.3725
#   young_wolf: 0.3457
#   walking_ballista: 0.3194
#   basking_broodscale: 0.3061
#   grist_the_hunger_tide: 0.2583
#   dredgers_insight: 0.2556
#   malevolent_rumble: 0.2124
#   overgrown_tomb: 0.1852
#   blade_of_the_bloodchief: 0.1784
#
# Cluster 23:
#   delighted_halfling: 0.3508
#   agathas_soul_cauldron: 0.3341
#   yawgmoth_thran_physician: 0.3173
#   young_wolf: 0.3142
#   spymasters_vault: 0.2159
#   grist_the_hunger_tide: 0.2096
#   badgermole_cub: 0.1971
#   walking_ballista: 0.1871
#   dredgers_insight: 0.1801
#   malevolent_rumble: 0.1756
#
# Cluster 24:
#   utopia_sprawl: 0.3630
#   sowing_mycospawn: 0.3272
#   talisman_of_impulse: 0.3222
#   ugins_labyrinth: 0.2714
#   eldrazi_temple: 0.2537
#   kozileks_command: 0.2528
#   malevolent_rumble: 0.2377
#   emrakul_the_promised_end: 0.2163
#   kozileks_return: 0.2076
#   icetill_explorer: 0.1750
#
# Cluster 25:
#   reprieve: 0.3439
#   path_to_exile: 0.2856
#   demolition_field: 0.2660
#   white_orchid_phantom: 0.2536
#   field_of_ruin: 0.2328
#   sunken_citadel: 0.2286
#   cleansing_wildfire: 0.1785
#   price_of_freedom: 0.1688
#   wrath_of_the_skies: 0.1410
#   solitude: 0.1212
#
# Cluster 26:
#   hollow_one: 0.3217
#   detectives_phoenix: 0.3085
#   burning_inquiry: 0.3079
#   marauding_mako: 0.3000
#   street_wraith: 0.2866
#   faithless_looting: 0.2469
#   goblin_lore: 0.1837
#   vengevine: 0.1805
#   blazing_rootwalla: 0.1765
#   nethergoyf: 0.1698
#
# Cluster 27:
#   basking_broodscale: 0.3581
#   ancient_stirrings: 0.3481
#   sowing_mycospawn: 0.3312
#   glaring_fleshraker: 0.3017
#   blade_of_the_bloodchief: 0.2790
#   icetill_explorer: 0.2773
#   eldrazi_temple: 0.2634
#   kozileks_command: 0.2621
#   malevolent_rumble: 0.2467
#   emrakul_the_promised_end: 0.2197
#
# Cluster 28:
#   talisman_of_dominance: 0.3920
#   portent_of_calamity: 0.3810
#   urzas_power_plant: 0.2626
#   urzas_tower: 0.2625
#   urzas_mine: 0.2625
#   expedition_map: 0.2606
#   karn_the_great_creator: 0.2593
#   ugins_labyrinth: 0.2238
#   ugin_eye_of_the_storms: 0.2216
#   kozileks_command: 0.2085
#
# Cluster 29:
#   grove_of_the_burnwillows: 0.3427
#   basking_broodscale: 0.3370
#   ancient_stirrings: 0.3349
#   glaring_fleshraker: 0.2839
#   devourer_of_destiny: 0.2677
#   blade_of_the_bloodchief: 0.2626
#   eldrazi_temple: 0.2479
#   kozileks_command: 0.2467
#   ugins_labyrinth: 0.2386
#   malevolent_rumble: 0.2322
#
# Cluster 30:
#   grove_of_the_burnwillows: 0.3636
#   basking_broodscale: 0.3470
#   glaring_fleshraker: 0.2924
#   emrakul_the_promised_end: 0.2838
#   blade_of_the_bloodchief: 0.2775
#   devourer_of_destiny: 0.2741
#   ugins_labyrinth: 0.2728
#   eldrazi_temple: 0.2553
#   kozileks_command: 0.2541
#   malevolent_rumble: 0.2391
#
# Cluster 31:
#   song_of_creation: 0.5141
#   repeal: 0.3405
#   mox_amber: 0.3033
#   emry_lurker_of_the_loch: 0.2938
#   tamiyo_inquisitive_student: 0.2768
#   mox_opal: 0.2428
#   malevolent_rumble: 0.2148
#   mishras_bauble: 0.1971
#   six: 0.1704
#   engineered_explosives: 0.1278
#
# Cluster 32:
#   mind_stone: 0.2938
#   urzas_tower: 0.2893
#   urzas_mine: 0.2893
#   urzas_power_plant: 0.2884
#   expedition_map: 0.2859
#   karn_the_great_creator: 0.2852
#   thought-knot_seer: 0.2647
#   devourer_of_destiny: 0.2470
#   ugins_labyrinth: 0.2467
#   eldrazi_temple: 0.2300
#
# Cluster 33:
#   talisman_of_resilience: 0.3918
#   sowing_mycospawn: 0.2791
#   urzas_power_plant: 0.2740
#   urzas_tower: 0.2739
#   urzas_mine: 0.2739
#   karn_the_great_creator: 0.2706
#   expedition_map: 0.2488
#   thought-knot_seer: 0.2382
#   ugins_labyrinth: 0.2304
#   devourer_of_destiny: 0.2283
#
# Cluster 34:
#   jeskai_ascendancy: 0.3951
#   repeal: 0.3715
#   mox_amber: 0.3502
#   emry_lurker_of_the_loch: 0.3124
#   tamiyo_inquisitive_student: 0.2871
#   portable_hole: 0.2743
#   mox_opal: 0.2440
#   cori-steel_cutter: 0.2388
#   metallic_rebuke: 0.1986
#   mishras_bauble: 0.1980
#
# Cluster 35:
#   emry_lurker_of_the_loch: 0.3532
#   tamiyo_inquisitive_student: 0.3330
#   repeal: 0.3189
#   mox_amber: 0.3155
#   metallic_rebuke: 0.2810
#   mox_opal: 0.2759
#   cori-steel_cutter: 0.2669
#   unholy_heat: 0.2458
#   mishras_bauble: 0.2239
#   urzas_saga: 0.2006
#
# Cluster 36:
#   tarmogoyf: 0.4582
#   wrenn_and_six: 0.2582
#   thoughtseize: 0.1964
#   inquisition_of_kozilek: 0.1962
#   fatal_push: 0.1814
#   nethergoyf: 0.1693
#   liliana_of_the_veil: 0.1529
#   urzas_saga: 0.1385
#   overgrown_tomb: 0.1080
#   dark_confidant: 0.1046
#
# Cluster 37:
#   soul_spike: 0.3610
#   necrodominance: 0.3475
#   sheoldred_the_apocalypse: 0.2613
#   march_of_wretched_sorrow: 0.2611
#   fell_the_profane: 0.2599
#   boggart_trawler: 0.2460
#   orcish_bowmasters: 0.1464
#   fatal_push: 0.1418
#   dreams_of_steel_and_oil: 0.1414
#   force_of_despair: 0.1412
#
# Cluster 38:
#   omnath_locus_of_creation: 0.4457
#   shardless_agent: 0.3352
#   magmatic_hellkite: 0.3159
#   birthing_ritual: 0.3111
#   leyline_binding: 0.2684
#   subtlety: 0.1868
#   solitude: 0.1683
#   quantum_riddler: 0.1550
#   bloodbraid_elf: 0.1219
#   witch_enchanter: 0.0863
#
# Cluster 39:
#   persist: 0.3883
#   archon_of_cruelty: 0.3804
#   unearth: 0.3465
#   thought_scour: 0.3114
#   faithless_looting: 0.3008
#   abhorrent_oculus: 0.2727
#   fatal_push: 0.2234
#   emperor_of_bones: 0.2116
#   psychic_frog: 0.2087
#   thoughtseize: 0.1858
#
# Cluster 40:
#   asmoranomardicadaistinaculdacar: 0.3811
#   ovalchase_daredevil: 0.3728
#   the_underworld_cookbook: 0.3637
#   monument_to_endurance: 0.1948
#   natures_rhythm: 0.1833
#   academy_manufactor: 0.1410
#   gilded_goose: 0.1323
#   psychic_frog: 0.1251
#   street_wraith: 0.0969
#   gingerbread_cabin: 0.0954
#
# Cluster 41:
#   thoughtcast: 0.3208
#   pinnacle_emissary: 0.3189
#   kappa_cannoneer: 0.3174
#   emry_lurker_of_the_loch: 0.3073
#   metallic_rebuke: 0.3053
#   mox_opal: 0.3015
#   tamiyo_inquisitive_student: 0.2620
#   mishras_bauble: 0.2447
#   urzas_saga: 0.2210
#   engineered_explosives: 0.2123
#
# Cluster 42:
#   grove_of_the_burnwillows: 0.3604
#   ancient_stirrings: 0.3451
#   basking_broodscale: 0.3440
#   blade_of_the_bloodchief: 0.3320
#   glaring_fleshraker: 0.2898
#   writhing_chrysalis: 0.2720
#   eldrazi_temple: 0.2530
#   kozileks_command: 0.2518
#   malevolent_rumble: 0.2370
#   urzas_saga: 0.1963
#
# Cluster 43:
#   amulet_of_vigor: 0.3183
#   primeval_titan: 0.3182
#   arboreal_grazer: 0.3129
#   spelunking: 0.3074
#   crumbling_vestige: 0.2905
#   malevolent_rumble: 0.2889
#   simic_growth_chamber: 0.2468
#   urzas_saga: 0.2394
#   green_suns_zenith: 0.2054
#   scapeshift: 0.1788
#
# Cluster 44:
#   grove_of_the_burnwillows: 0.3619
#   ancient_stirrings: 0.3466
#   blade_of_the_bloodchief: 0.3454
#   basking_broodscale: 0.3454
#   glaring_fleshraker: 0.2910
#   writhing_chrysalis: 0.2652
#   eldrazi_temple: 0.2541
#   kozileks_command: 0.2529
#   malevolent_rumble: 0.2380
#   urzas_saga: 0.1972
#
# Cluster 45:
#   grove_of_the_burnwillows: 0.3652
#   ancient_stirrings: 0.3497
#   blade_of_the_bloodchief: 0.3485
#   basking_broodscale: 0.3485
#   glaring_fleshraker: 0.2936
#   eldrazi_temple: 0.2564
#   kozileks_command: 0.2551
#   malevolent_rumble: 0.2401
#   urzas_saga: 0.1990
#   walking_ballista: 0.1817
#
# Cluster 46:
#   essence_flux: 0.4032
#   ice-fang_coatl: 0.3667
#   coiling_oracle: 0.3398
#   abhorrent_oculus: 0.3336
#   birthing_ritual: 0.3321
#   flare_of_denial: 0.2668
#   subtlety: 0.2448
#   sink_into_stupor: 0.2074
#   quantum_riddler: 0.1685
#   harbinger_of_the_seas: 0.1628
#
# Cluster 47:
#   wrenn_and_six: 0.4070
#   omnath_locus_of_creation: 0.3839
#   eternal_witness: 0.3589
#   orims_chant: 0.3570
#   stock_up: 0.2560
#   galvanic_discharge: 0.2165
#   solitude: 0.2034
#   quantum_riddler: 0.1904
#   teferi_time_raveler: 0.1672
#   ephemerate: 0.1493
#
# Cluster 48:
#   territorial_kavu: 0.3929
#   leyline_of_the_guildpact: 0.3918
#   scion_of_draco: 0.3909
#   leyline_binding: 0.3798
#   lightning_bolt: 0.2622
#   ragavan_nimble_pilferer: 0.2457
#   phlage_titan_of_fires_fury: 0.1962
#   quantum_riddler: 0.1905
#   consign_to_memory: 0.1723
#   stubborn_denial: 0.1516
#
# Cluster 49:
#   crumbling_vestige: 0.3110
#   spelunking: 0.3107
#   amulet_of_vigor: 0.3104
#   primeval_titan: 0.3103
#   arboreal_grazer: 0.3091
#   green_suns_zenith: 0.3074
#   gruul_turf: 0.3065
#   simic_growth_chamber: 0.2347
#   scapeshift: 0.2335
#   urzas_saga: 0.2334
#
# Cluster 50:
#   crumbling_vestige: 0.3095
#   spelunking: 0.3092
#   amulet_of_vigor: 0.3088
#   arboreal_grazer: 0.3076
#   green_suns_zenith: 0.3058
#   primeval_titan: 0.3024
#   simic_growth_chamber: 0.3004
#   urzas_saga: 0.2322
#   scapeshift: 0.2281
#   gruul_turf: 0.2101
#
# Cluster 51:
#   amulet_of_vigor: 0.3204
#   primeval_titan: 0.3203
#   arboreal_grazer: 0.3192
#   spelunking: 0.3183
#   crumbling_vestige: 0.3137
#   simic_growth_chamber: 0.2524
#   scapeshift: 0.2411
#   urzas_saga: 0.2410
#   gruul_turf: 0.2299
#   explore: 0.2219
#
# Cluster 52:
#   flagstones_of_trokair: 0.3986
#   white_orchid_phantom: 0.3535
#   witch_enchanter: 0.3071
#   starfield_shepherd: 0.3017
#   ocelot_pride: 0.2856
#   guide_of_souls: 0.2839
#   phelia_exuberant_shepherd: 0.2430
#   ephemerate: 0.2098
#   solitude: 0.1982
#   quantum_riddler: 0.1933
#
# Cluster 53:
#   spelunking: 0.3168
#   amulet_of_vigor: 0.3164
#   primeval_titan: 0.3163
#   arboreal_grazer: 0.3152
#   crumbling_vestige: 0.3100
#   simic_growth_chamber: 0.2534
#   scapeshift: 0.2381
#   urzas_saga: 0.2380
#   green_suns_zenith: 0.2362
#   gruul_turf: 0.2332
#
# Cluster 54:
#   explore: 0.3648
#   spelunking: 0.3044
#   amulet_of_vigor: 0.3040
#   primeval_titan: 0.3039
#   arboreal_grazer: 0.3014
#   crumbling_vestige: 0.2963
#   simic_growth_chamber: 0.2638
#   urzas_saga: 0.2286
#   scapeshift: 0.2286
#   gruul_turf: 0.2060
#
# Cluster 55:
#   flame_of_anor: 0.3563
#   thundertrap_trainer: 0.3246
#   snapcaster_mage: 0.2712
#   flare_of_denial: 0.1941
#   tamiyo_inquisitive_student: 0.1724
#   counterspell: 0.1722
#   phlage_titan_of_fires_fury: 0.1272
#   lightning_bolt: 0.0980
#   galvanic_discharge: 0.0972
#   consult_the_star_charts: 0.0963
#
# Cluster 56:
#   counterspell: 0.3281
#   psychic_frog: 0.2961
#   fatal_push: 0.2876
#   tamiyo_inquisitive_student: 0.2760
#   orcish_bowmasters: 0.2230
#   thoughtseize: 0.2228
#   subtlety: 0.2173
#   kaito_bane_of_nightmares: 0.2003
#   force_of_negation: 0.1743
#   darkslick_shores: 0.1641
#
# Cluster 57:
#   slickshot_show-off: 0.3293
#   lava_dart: 0.3266
#   monastery_swiftspear: 0.3257
#   dragons_rage_channeler: 0.3255
#   cori-steel_cutter: 0.3205
#   expressive_iteration: 0.3155
#   preordain: 0.2967
#   mishras_bauble: 0.2597
#   mutagenic_growth: 0.2479
#   lightning_bolt: 0.2478
#
# Cluster 58:
#   territorial_kavu: 0.3708
#   leyline_of_the_guildpact: 0.3697
#   scion_of_draco: 0.3689
#   doorkeeper_thrull: 0.3632
#   leyline_binding: 0.3312
#   tribal_flames: 0.2531
#   lightning_bolt: 0.2454
#   ragavan_nimble_pilferer: 0.2319
#   phlage_titan_of_fires_fury: 0.2254
#   stubborn_denial: 0.2162
#
# Cluster 59:
#   coiling_oracle: 0.3724
#   ice-fang_coatl: 0.3718
#   shardless_agent: 0.3628
#   abhorrent_oculus: 0.3495
#   birthing_ritual: 0.3367
#   flare_of_denial: 0.2916
#   subtlety: 0.2604
#   sink_into_stupor: 0.2134
#   harbinger_of_the_seas: 0.1723
#   fblthp_the_lost: 0.1493
#
# Cluster 60:
#   overlord_of_the_balemurk: 0.4325
#   psychic_frog: 0.3396
#   subtlety: 0.3365
#   phelia_exuberant_shepherd: 0.3137
#   quantum_riddler: 0.2494
#   force_of_negation: 0.2387
#   hydroelectric_specimen: 0.2065
#   fatal_push: 0.2008
#   consign_to_memory: 0.1614
#   teferi_time_raveler: 0.1357
#
# Cluster 61:
#   galvanic_discharge: 0.3777
#   consign_to_memory: 0.3172
#   phlage_titan_of_fires_fury: 0.3151
#   solitude: 0.3026
#   quantum_riddler: 0.3024
#   teferi_time_raveler: 0.2438
#   supreme_verdict: 0.2325
#   prismatic_ending: 0.2109
#   spell_snare: 0.2106
#   wrath_of_the_skies: 0.2067
#
# Cluster 62:
#   doorkeeper_thrull: 0.3883
#   territorial_kavu: 0.3665
#   leyline_of_the_guildpact: 0.3655
#   scion_of_draco: 0.3646
#   leyline_binding: 0.3543
#   lightning_bolt: 0.2452
#   nulldrifter: 0.2402
#   stubborn_denial: 0.2290
#   phlage_titan_of_fires_fury: 0.2206
#   ragavan_nimble_pilferer: 0.1925
#
# Cluster 63:
#   doorkeeper_thrull: 0.3896
#   territorial_kavu: 0.3677
#   leyline_of_the_guildpact: 0.3667
#   scion_of_draco: 0.3659
#   leyline_binding: 0.3555
#   lightning_bolt: 0.2475
#   nulldrifter: 0.2410
#   ragavan_nimble_pilferer: 0.2300
#   phlage_titan_of_fires_fury: 0.2222
#   consign_to_memory: 0.2217
#
# Cluster 64:
#   slickshot_show-off: 0.3335
#   lava_dart: 0.3307
#   expressive_iteration: 0.3305
#   monastery_swiftspear: 0.3299
#   dragons_rage_channeler: 0.3296
#   cori-steel_cutter: 0.3245
#   preordain: 0.3025
#   mishras_bauble: 0.2630
#   lightning_bolt: 0.2509
#   violent_urge: 0.1678
#
# Cluster 65:
#   slickshot_show-off: 0.3287
#   lava_dart: 0.3260
#   expressive_iteration: 0.3258
#   monastery_swiftspear: 0.3252
#   dragons_rage_channeler: 0.3249
#   cori-steel_cutter: 0.3199
#   preordain: 0.2982
#   mishras_bauble: 0.2592
#   mutagenic_growth: 0.2527
#   lightning_bolt: 0.2474
#
# Cluster 66:
#   coiling_oracle: 0.3750
#   ice-fang_coatl: 0.3743
#   shardless_agent: 0.3652
#   abhorrent_oculus: 0.3519
#   birthing_ritual: 0.3390
#   flare_of_denial: 0.2936
#   sink_into_stupor: 0.2148
#   subtlety: 0.1966
#   harbinger_of_the_seas: 0.1791
#   fblthp_the_lost: 0.1603
#
# Cluster 67:
#   coiling_oracle: 0.3741
#   ice-fang_coatl: 0.3735
#   shardless_agent: 0.3644
#   abhorrent_oculus: 0.3511
#   birthing_ritual: 0.3383
#   flare_of_denial: 0.2929
#   sink_into_stupor: 0.2144
#   fblthp_the_lost: 0.2051
#   subtlety: 0.1962
#   harbinger_of_the_seas: 0.1762
#
# Cluster 68:
#   arcbound_ravager: 0.3621
#   ornithopter: 0.3056
#   weapons_manufacturing: 0.2898
#   spirebluff_canal: 0.2746
#   pinnacle_emissary: 0.2744
#   kappa_cannoneer: 0.2731
#   memnite: 0.2673
#   mox_opal: 0.2595
#   springleaf_drum: 0.2354
#   mishras_bauble: 0.2106
#
# Cluster 69:
#   slickshot_show-off: 0.3302
#   lava_dart: 0.3275
#   expressive_iteration: 0.3267
#   monastery_swiftspear: 0.3266
#   dragons_rage_channeler: 0.3263
#   cori-steel_cutter: 0.3213
#   preordain: 0.2995
#   mishras_bauble: 0.2603
#   lightning_bolt: 0.2484
#   mutagenic_growth: 0.2468
#
# Cluster 70:
#   slickshot_show-off: 0.3260
#   mutagenic_growth: 0.3249
#   lava_dart: 0.3233
#   expressive_iteration: 0.3231
#   dragons_rage_channeler: 0.3222
#   monastery_swiftspear: 0.3173
#   cori-steel_cutter: 0.3172
#   preordain: 0.2957
#   mishras_bauble: 0.2570
#   lightning_bolt: 0.2453
#
# Cluster 71:
#   slickshot_show-off: 0.3249
#   lava_dart: 0.3222
#   monastery_swiftspear: 0.3213
#   dragons_rage_channeler: 0.3211
#   mutagenic_growth: 0.3206
#   expressive_iteration: 0.3204
#   cori-steel_cutter: 0.3162
#   preordain: 0.2947
#   mishras_bauble: 0.2562
#   lightning_bolt: 0.2445
#
# Cluster 72:
#   ornithopter: 0.3458
#   thoughtcast: 0.2831
#   pinnacle_emissary: 0.2781
#   kappa_cannoneer: 0.2768
#   mox_opal: 0.2629
#   memnite: 0.2613
#   thought_monitor: 0.2607
#   spirebluff_canal: 0.2589
#   springleaf_drum: 0.2535
#   mishras_bauble: 0.2134
#
# Cluster 73:
#   slickshot_show-off: 0.3231
#   lava_dart: 0.3204
#   monastery_swiftspear: 0.3195
#   dragons_rage_channeler: 0.3193
#   mutagenic_growth: 0.3159
#   cori-steel_cutter: 0.3144
#   expressive_iteration: 0.3142
#   preordain: 0.2930
#   mishras_bauble: 0.2547
#   lightning_bolt: 0.2431
#
# Cluster 74:
#   doorkeeper_thrull: 0.3959
#   territorial_kavu: 0.3736
#   leyline_of_the_guildpact: 0.3726
#   scion_of_draco: 0.3717
#   leyline_binding: 0.3611
#   lightning_bolt: 0.2515
#   stubborn_denial: 0.2383
#   ragavan_nimble_pilferer: 0.2337
#   phlage_titan_of_fires_fury: 0.2290
#   consign_to_memory: 0.1142
#
# Cluster 75:
#   thoughtcast: 0.3414
#   pinnacle_emissary: 0.3354
#   kappa_cannoneer: 0.3338
#   mox_opal: 0.3171
#   mishras_bauble: 0.2573
#   memnite: 0.2552
#   engineered_explosives: 0.2531
#   tormods_crypt: 0.2460
#   urzas_saga: 0.2323
#   sink_into_stupor: 0.2252
#
# Cluster 76:
#   doorkeeper_thrull: 0.3894
#   territorial_kavu: 0.3675
#   leyline_of_the_guildpact: 0.3664
#   scion_of_draco: 0.3656
#   leyline_binding: 0.3552
#   stubborn_denial: 0.2722
#   lightning_bolt: 0.2474
#   ragavan_nimble_pilferer: 0.2298
#   phlage_titan_of_fires_fury: 0.2252
#   arena_of_glory: 0.1117
#
# Cluster 77:
#   doorkeeper_thrull: 0.3985
#   territorial_kavu: 0.3761
#   leyline_of_the_guildpact: 0.3751
#   scion_of_draco: 0.3742
#   leyline_binding: 0.3636
#   lightning_bolt: 0.2519
#   ragavan_nimble_pilferer: 0.2353
#   phlage_titan_of_fires_fury: 0.2305
#   stubborn_denial: 0.1938
#   winternight_stories: 0.1180
#
# Cluster 78:
#   slickshot_show-off: 0.3284
#   lava_dart: 0.3257
#   expressive_iteration: 0.3254
#   monastery_swiftspear: 0.3248
#   dragons_rage_channeler: 0.3246
#   cori-steel_cutter: 0.3196
#   preordain: 0.2978
#   mishras_bauble: 0.2589
#   lightning_bolt: 0.2471
#   mutagenic_growth: 0.2454
#
# Cluster 79:
#   slickshot_show-off: 0.3239
#   mutagenic_growth: 0.3228
#   lava_dart: 0.3212
#   monastery_swiftspear: 0.3204
#   dragons_rage_channeler: 0.3201
#   expressive_iteration: 0.3155
#   cori-steel_cutter: 0.3152
#   preordain: 0.2938
#   mishras_bauble: 0.2554
#   lightning_bolt: 0.2437
#
# Cluster 80:
#   narset_parter_of_veils: 0.4503
#   orims_chant: 0.4398
#   consult_the_star_charts: 0.3031
#   counterspell: 0.2604
#   solitude: 0.2234
#   days_undoing: 0.2087
#   supreme_verdict: 0.2007
#   teferi_time_raveler: 0.1798
#   prismatic_ending: 0.1755
#   spell_snare: 0.1628
#
# Cluster 81:
#   narset_parter_of_veils: 0.4618
#   orims_chant: 0.4421
#   teferi_time_raveler: 0.2474
#   days_undoing: 0.2320
#   solitude: 0.2291
#   consult_the_star_charts: 0.2272
#   supreme_verdict: 0.2255
#   lã³rien_revealed: 0.2162
#   counterspell: 0.1981
#   prismatic_ending: 0.1816
#
# Cluster 82:
#   goryos_vengeance: 0.3848
#   atraxa_grand_unifier: 0.3707
#   jace_vryns_prodigy: 0.3395
#   psychic_frog: 0.3325
#   thoughtseize: 0.3084
#   faithful_mending: 0.2869
#   ephemerate: 0.2620
#   solitude: 0.2458
#   quantum_riddler: 0.2433
#   force_of_negation: 0.2321
#
# Cluster 83:
#   ornithopter: 0.3373
#   pinnacle_emissary: 0.2981
#   kappa_cannoneer: 0.2966
#   spirebluff_canal: 0.2917
#   thoughtcast: 0.2883
#   mox_opal: 0.2818
#   memnite: 0.2809
#   springleaf_drum: 0.2535
#   mishras_bauble: 0.2287
#   engineered_explosives: 0.2194
#
# Cluster 84:
#   gruul_turf: 0.3165
#   spelunking: 0.3147
#   amulet_of_vigor: 0.3143
#   primeval_titan: 0.3142
#   arboreal_grazer: 0.3130
#   malevolent_rumble: 0.2853
#   boseiju_who_endures: 0.2409
#   crumbling_vestige: 0.2408
#   urzas_saga: 0.2364
#   green_suns_zenith: 0.2334
#
# Cluster 85:
#   spelunking: 0.3185
#   amulet_of_vigor: 0.3182
#   primeval_titan: 0.3181
#   arboreal_grazer: 0.3169
#   crumbling_vestige: 0.3144
#   malevolent_rumble: 0.2888
#   simic_growth_chamber: 0.2428
#   gruul_turf: 0.2403
#   urzas_saga: 0.2393
#   green_suns_zenith: 0.2363
#
# Cluster 86:
#   spelunking: 0.3188
#   amulet_of_vigor: 0.3184
#   primeval_titan: 0.3183
#   arboreal_grazer: 0.3171
#   crumbling_vestige: 0.3022
#   malevolent_rumble: 0.2890
#   simic_growth_chamber: 0.2450
#   gruul_turf: 0.2405
#   urzas_saga: 0.2395
#   scapeshift: 0.2142
#
# Cluster 87:
#   gruul_turf: 0.3204
#   amulet_of_vigor: 0.3181
#   primeval_titan: 0.3180
#   spelunking: 0.3177
#   arboreal_grazer: 0.3169
#   malevolent_rumble: 0.2888
#   crumbling_vestige: 0.2544
#   urzas_saga: 0.2392
#   boseiju_who_endures: 0.2258
#   simic_growth_chamber: 0.2153
#
# Cluster 88:
#   spelunking: 0.3237
#   amulet_of_vigor: 0.3233
#   primeval_titan: 0.3232
#   arboreal_grazer: 0.3220
#   malevolent_rumble: 0.2935
#   crumbling_vestige: 0.2908
#   simic_growth_chamber: 0.2474
#   gruul_turf: 0.2442
#   urzas_saga: 0.2431
#   boseiju_who_endures: 0.2004
#
# Cluster 89:
#   spelunking: 0.3246
#   amulet_of_vigor: 0.3242
#   primeval_titan: 0.3241
#   arboreal_grazer: 0.3229
#   malevolent_rumble: 0.2943
#   crumbling_vestige: 0.2705
#   simic_growth_chamber: 0.2498
#   gruul_turf: 0.2449
#   urzas_saga: 0.2438
#   boseiju_who_endures: 0.2048
#
# Cluster 90:
#   thoughtcast: 0.3203
#   pinnacle_emissary: 0.3146
#   kappa_cannoneer: 0.3131
#   spirebluff_canal: 0.3059
#   mox_opal: 0.2974
#   memnite: 0.2460
#   mishras_bauble: 0.2414
#   metallic_rebuke: 0.2402
#   engineered_explosives: 0.2334
#   sink_into_stupor: 0.2292
#
# Cluster 91:
#   overlord_of_the_balemurk: 0.4021
#   witch_enchanter: 0.3714
#   fatal_push: 0.3357
#   flickerwisp: 0.3294
#   thoughtseize: 0.2923
#   emperor_of_bones: 0.2919
#   phelia_exuberant_shepherd: 0.2844
#   ephemerate: 0.2384
#   solitude: 0.2263
#   quantum_riddler: 0.2262
#
# Cluster 92:
#   overlord_of_the_balemurk: 0.4060
#   witch_enchanter: 0.3751
#   fatal_push: 0.3390
#   flickerwisp: 0.3326
#   thoughtseize: 0.2952
#   emperor_of_bones: 0.2948
#   phelia_exuberant_shepherd: 0.2872
#   solitude: 0.2285
#   quantum_riddler: 0.2284
#   ephemerate: 0.1880
#
# Cluster 93:
#   thoughtcast: 0.3125
#   spirebluff_canal: 0.3120
#   pinnacle_emissary: 0.3070
#   kappa_cannoneer: 0.3055
#   mox_opal: 0.2902
#   engineered_explosives: 0.2796
#   memnite: 0.2725
#   metallic_rebuke: 0.2367
#   mishras_bauble: 0.2355
#   tormods_crypt: 0.2296
#
# Cluster 94:
#   metallic_rebuke: 0.3030
#   engineered_explosives: 0.3015
#   thoughtcast: 0.3015
#   spirebluff_canal: 0.3010
#   memnite: 0.2975
#   pinnacle_emissary: 0.2961
#   kappa_cannoneer: 0.2947
#   mox_opal: 0.2799
#   fiery_islet: 0.2296
#   mishras_bauble: 0.2272
#
# Cluster 95:
#   thoughtcast: 0.3107
#   spirebluff_canal: 0.3102
#   memnite: 0.3096
#   pinnacle_emissary: 0.3051
#   kappa_cannoneer: 0.3037
#   mox_opal: 0.2885
#   engineered_explosives: 0.2517
#   metallic_rebuke: 0.2371
#   mishras_bauble: 0.2341
#   fiery_islet: 0.2328
#
# Cluster 96:
#   ajani_nacatl_pariah: 0.3734
#   ocelot_pride: 0.3576
#   guide_of_souls: 0.3569
#   galvanic_discharge: 0.3259
#   goblin_bombardment: 0.2800
#   ragavan_nimble_pilferer: 0.2639
#   seasoned_pyromancer: 0.2615
#   phlage_titan_of_fires_fury: 0.2586
#   sacred_foundry: 0.1961
#   arena_of_glory: 0.1923
#
# Cluster 97:
#   ajani_nacatl_pariah: 0.3763
#   ocelot_pride: 0.3604
#   guide_of_souls: 0.3597
#   galvanic_discharge: 0.3284
#   goblin_bombardment: 0.2822
#   ragavan_nimble_pilferer: 0.2660
#   phlage_titan_of_fires_fury: 0.2607
#   sacred_foundry: 0.2041
#   seasoned_pyromancer: 0.1946
#   arena_of_glory: 0.1938
#
# Cluster 98:
#   ajani_nacatl_pariah: 0.3701
#   ocelot_pride: 0.3545
#   guide_of_souls: 0.3538
#   galvanic_discharge: 0.3230
#   seasoned_pyromancer: 0.2802
#   goblin_bombardment: 0.2776
#   ragavan_nimble_pilferer: 0.2616
#   phlage_titan_of_fires_fury: 0.2564
#   thraben_charm: 0.2055
#   voice_of_victory: 0.1990
#
# Cluster 99:
#   ajani_nacatl_pariah: 0.3684
#   ocelot_pride: 0.3528
#   guide_of_souls: 0.3522
#   galvanic_discharge: 0.3215
#   seasoned_pyromancer: 0.2789
#   goblin_bombardment: 0.2763
#   ragavan_nimble_pilferer: 0.2604
#   phlage_titan_of_fires_fury: 0.2301
#   static_prison: 0.2133
#   sacred_foundry: 0.1906
#
# Cluster 100:
#   ajani_nacatl_pariah: 0.3616
#   seasoned_pyromancer: 0.3589
#   ocelot_pride: 0.3463
#   guide_of_souls: 0.3457
#   galvanic_discharge: 0.3156
#   goblin_bombardment: 0.2712
#   ragavan_nimble_pilferer: 0.2556
#   phlage_titan_of_fires_fury: 0.2505
#   static_prison: 0.2094
#   sacred_foundry: 0.1940
#
# Cluster 101:
#   ajani_nacatl_pariah: 0.3709
#   ocelot_pride: 0.3552
#   guide_of_souls: 0.3546
#   galvanic_discharge: 0.3237
#   seasoned_pyromancer: 0.2808
#   goblin_bombardment: 0.2782
#   ragavan_nimble_pilferer: 0.2622
#   phlage_titan_of_fires_fury: 0.2562
#   sacred_foundry: 0.1955
#   voice_of_victory: 0.1907
#
# Cluster 102:
#   seasoned_pyromancer: 0.3644
#   ajani_nacatl_pariah: 0.3611
#   ocelot_pride: 0.3458
#   guide_of_souls: 0.3451
#   galvanic_discharge: 0.3151
#   goblin_bombardment: 0.2708
#   ragavan_nimble_pilferer: 0.2552
#   phlage_titan_of_fires_fury: 0.2501
#   sacred_foundry: 0.1934
#   arena_of_glory: 0.1860
#
# Cluster 103:
#   seasoned_pyromancer: 0.3650
#   ajani_nacatl_pariah: 0.3617
#   ocelot_pride: 0.3464
#   guide_of_souls: 0.3458
#   galvanic_discharge: 0.3157
#   goblin_bombardment: 0.2713
#   ragavan_nimble_pilferer: 0.2557
#   phlage_titan_of_fires_fury: 0.2505
#   thraben_charm: 0.1903
#   sacred_foundry: 0.1899
#
# Cluster 104:
#   goryos_vengeance: 0.4119
#   atraxa_grand_unifier: 0.3968
#   psychic_frog: 0.3559
#   faithful_mending: 0.3109
#   ephemerate: 0.2805
#   solitude: 0.2630
#   quantum_riddler: 0.2629
#   thoughtseize: 0.2527
#   force_of_negation: 0.2160
#   prismatic_ending: 0.1946
#
# Cluster 105:
#   goryos_vengeance: 0.4156
#   atraxa_grand_unifier: 0.4003
#   psychic_frog: 0.3591
#   faithful_mending: 0.3137
#   ephemerate: 0.2830
#   solitude: 0.2654
#   quantum_riddler: 0.2652
#   force_of_negation: 0.2260
#   prismatic_ending: 0.2086
#   thoughtseize: 0.1714
#
# Cluster 106:
#   ajani_nacatl_pariah: 0.3670
#   ocelot_pride: 0.3515
#   guide_of_souls: 0.3509
#   galvanic_discharge: 0.3203
#   seasoned_pyromancer: 0.2778
#   goblin_bombardment: 0.2753
#   ragavan_nimble_pilferer: 0.2594
#   phlage_titan_of_fires_fury: 0.2542
#   thraben_charm: 0.2050
#   voice_of_victory: 0.1985
#
# Cluster 107:
#   ajani_nacatl_pariah: 0.3642
#   ocelot_pride: 0.3487
#   guide_of_souls: 0.3481
#   galvanic_discharge: 0.3178
#   seasoned_pyromancer: 0.2757
#   goblin_bombardment: 0.2731
#   voice_of_victory: 0.2650
#   ragavan_nimble_pilferer: 0.2574
#   thraben_charm: 0.2549
#   phlage_titan_of_fires_fury: 0.2522
#
# Cluster 108:
#   phelia_exuberant_shepherd: 0.3894
#   phlage_titan_of_fires_fury: 0.3287
#   fable_of_the_mirror-breaker: 0.3108
#   solitude: 0.3098
#   quantum_riddler: 0.3096
#   march_of_otherworldly_light: 0.3077
#   ragavan_nimble_pilferer: 0.2516
#   consign_to_memory: 0.2513
#   strix_serenade: 0.2292
#   teferi_time_raveler: 0.1762
#
# Cluster 109:
#   faithful_mending: 0.4043
#   goryos_vengeance: 0.4039
#   atraxa_grand_unifier: 0.3891
#   psychic_frog: 0.3490
#   ephemerate: 0.2750
#   solitude: 0.2580
#   quantum_riddler: 0.2578
#   thoughtseize: 0.2464
#   force_of_negation: 0.2034
#   prismatic_ending: 0.1366
#
# Cluster 110:
#   phelia_exuberant_shepherd: 0.3584
#   phlage_titan_of_fires_fury: 0.3377
#   solitude: 0.3182
#   quantum_riddler: 0.3180
#   consign_to_memory: 0.3132
#   ragavan_nimble_pilferer: 0.3092
#   fable_of_the_mirror-breaker: 0.2371
#   strix_serenade: 0.2240
#   galvanic_discharge: 0.2140
#   teferi_time_raveler: 0.1877
#
# Cluster 111:
#   faithful_mending: 0.4039
#   goryos_vengeance: 0.4013
#   atraxa_grand_unifier: 0.3866
#   psychic_frog: 0.3467
#   ephemerate: 0.2733
#   solitude: 0.2563
#   quantum_riddler: 0.2561
#   force_of_negation: 0.2419
#   prismatic_ending: 0.1983
#   thoughtseize: 0.1655
#
# Cluster 112:
#   phelia_exuberant_shepherd: 0.3869
#   phlage_titan_of_fires_fury: 0.3278
#   solitude: 0.3089
#   quantum_riddler: 0.3087
#   march_of_otherworldly_light: 0.3025
#   fable_of_the_mirror-breaker: 0.3024
#   consign_to_memory: 0.2621
#   ragavan_nimble_pilferer: 0.2592
#   strix_serenade: 0.2301
#   teferi_time_raveler: 0.1743
#
# Cluster 113:
#   faithful_mending: 0.4019
#   goryos_vengeance: 0.3993
#   atraxa_grand_unifier: 0.3847
#   psychic_frog: 0.3450
#   ephemerate: 0.2719
#   solitude: 0.2550
#   quantum_riddler: 0.2549
#   thoughtseize: 0.2471
#   force_of_negation: 0.2148
#   prismatic_ending: 0.2004
#
# Cluster 114:
#   goryos_vengeance: 0.4002
#   faithful_mending: 0.3983
#   atraxa_grand_unifier: 0.3855
#   psychic_frog: 0.3458
#   ephemerate: 0.2725
#   solitude: 0.2556
#   quantum_riddler: 0.2554
#   thoughtseize: 0.2476
#   force_of_negation: 0.2153
#   prismatic_ending: 0.1921
#
# Cluster 115:
#   faithful_mending: 0.4037
#   goryos_vengeance: 0.4011
#   atraxa_grand_unifier: 0.3863
#   psychic_frog: 0.3465
#   ephemerate: 0.2731
#   solitude: 0.2561
#   quantum_riddler: 0.2560
#   thoughtseize: 0.2482
#   force_of_negation: 0.2157
#   teferi_time_raveler: 0.1410
#
# Cluster 116:
#   ragavan_nimble_pilferer: 0.3454
#   phlage_titan_of_fires_fury: 0.3416
#   consign_to_memory: 0.3413
#   solitude: 0.3225
#   quantum_riddler: 0.3223
#   phelia_exuberant_shepherd: 0.3055
#   teferi_time_raveler: 0.2579
#   prismatic_ending: 0.2404
#   fable_of_the_mirror-breaker: 0.2157
#   ephemerate: 0.1794
#
# Cluster 117:
#   phlage_titan_of_fires_fury: 0.3448
#   consign_to_memory: 0.3438
#   solitude: 0.3249
#   quantum_riddler: 0.3247
#   phelia_exuberant_shepherd: 0.3063
#   ragavan_nimble_pilferer: 0.3054
#   strix_serenade: 0.2404
#   teferi_time_raveler: 0.2377
#   fable_of_the_mirror-breaker: 0.2173
#   ephemerate: 0.1755

# %% [markdown]
# ## Merge similar clusters

# %%
# Parameters
similarity_threshold = 0.5

unique_clusters = sorted([c for c in df_train['cluster'].unique() if c != -1])

cluster_centroids = {}
for cluster in unique_clusters:
    cluster_indices = df_train.index[df_train['cluster'] == cluster].tolist()
    cluster_centroids[cluster] = X_train_reduced[cluster_indices].mean(axis=0)
centroids_matrix = np.vstack([cluster_centroids[c] for c in unique_clusters])

similarity_matrix = cosine_similarity(centroids_matrix)

merged_cluster_map = {}
current_new_label = 0
visited = set()
for i, cluster_i in enumerate(unique_clusters):
    if cluster_i in visited:
        continue
    # Start a new merged cluster
    merged_cluster_map[cluster_i] = current_new_label
    visited.add(cluster_i)
    # Merge similar clusters
    for j, cluster_j in enumerate(unique_clusters):
        if cluster_j in visited:
            continue
        if similarity_matrix[i, j] >= similarity_threshold:
            merged_cluster_map[cluster_j] = current_new_label
            visited.add(cluster_j)
    current_new_label += 1

# Apply merged clusters to the dataframe
df_train['merged_cluster'] = df_train['cluster'].map(lambda x: -1 if x == -1 else merged_cluster_map[x])


print("Old number of clusters:", len(unique_clusters))
print("New number of merged clusters:", df_train['merged_cluster'].nunique() - (1 if -1 in df_train['merged_cluster'].unique() else 0))

# Display top cards in merged clusters
for cluster_label in sorted(df_train["merged_cluster"].unique()):
    if cluster_label == -1:
        continue
    cluster_decks = df_train[df_train["merged_cluster"] == cluster_label]
    top_cards = {}
    for text in cluster_decks["deck_text"]:
        for card in text.split():
            top_cards[card] = top_cards.get(card, 0) + 1
    top_cards_sorted = sorted(top_cards.items(), key=lambda x: x[1], reverse=True)[:10]
    print(f"Cluster {cluster_label}: {top_cards_sorted}")
# Out:
# Old number of clusters: 118
# New number of merged clusters: 42
# Cluster 0: [('irencrag_feat', 92), ('strike_it_rich', 92), ('desperate_ritual', 92), ('pyretic_ritual', 92), ('goblin_charbelcher', 92), ('stormscale_scion', 91), ('pinnacle_monk', 90), ('manamorphose', 89), ('shatterskull_smashing', 86), ('sundering_eruption', 84)]
# Cluster 1: []
# Cluster 2: [('hydroelectric_specimen', 948), ('sink_into_stupor', 948), ('goblin_charbelcher', 948), ('lotus_bloom', 948), ('disrupting_shoal', 947), ('whir_of_invention', 947), ('sea_gate_restoration', 946), ('tameshi_reality_architect', 945), ('suppression_ray', 944), ('fallaji_archaeologist', 860)]
# Cluster 3: [('lightning_bolt', 132), ('lava_spike', 120), ('goblin_guide', 119), ('monastery_swiftspear', 116), ('skewer_the_critics', 112), ('boltwave', 106), ('searing_blaze', 105), ('boros_charm', 99), ('sunbaked_canyon', 95), ('rift_bolt', 86)]
# Cluster 4: [('hedron_crab', 428), ('ruin_crab', 428), ('archive_trap', 428), ('fractured_sanity', 425), ('surgical_extraction', 389), ('fatal_push', 365), ('drown_in_the_loch', 348), ('field_of_ruin', 344), ('tashas_hideous_laughter', 306), ('visions_of_beyond', 247)]
# Cluster 5: [('ral_monsoon_mage', 700), ('desperate_ritual', 700), ('manamorphose', 700), ('pyretic_ritual', 700), ('ruby_medallion', 700), ('reckless_impulse', 697), ('wrenns_resolve', 696), ('past_in_flames', 522), ('wish', 362), ('artists_talent', 331)]
# Cluster 6: [('allosaurus_rider', 200), ('eldritch_evolution', 200), ('neoform', 200), ('consign_to_memory', 200), ('planar_genesis', 200), ('summoners_pact', 200), ('pact_of_negation', 194), ('veil_of_summer', 182), ('hedge_maze', 150), ('disciple_of_freyalise', 114)]
# Cluster 7: [('stinkweed_imp', 116), ('creeping_chill', 116), ('golgari_thug', 108), ('faithless_looting', 102), ('arclight_phoenix', 80), ('lava_dart', 80), ('life_from_the_loam', 77), ('cathartic_reunion', 75), ('artists_talent', 74), ('stomping_ground', 46)]
# Cluster 8: [('puresteel_paladin', 101), ('mox_opal', 100), ('urzas_saga', 98), ('stoneforge_mystic', 92), ('colossus_hammer', 92), ('ornithopter', 87), ('leyline_axe', 84), ('battlefield_improvisation', 71), ('inkmoth_nexus', 56), ('memnite', 48)]
# Cluster 9: [('master_of_the_pearl_trident', 152), ('aether_vial', 146), ('sink_into_stupor', 132), ('silvergill_adept', 121), ('floodpits_drowner', 114), ('harbinger_of_the_seas', 113), ('lord_of_atlantis', 112), ('cavern_of_souls', 112), ('vodalian_hexcatcher', 110), ('tide_shaper', 101)]
# Cluster 10: [('might_of_old_krosa', 73), ('scale_up', 68), ('mutagenic_growth', 54), ('glistener_elf', 50), ('inkmoth_nexus', 44), ('vines_of_vastwood', 39), ('ignoble_hierarch', 38), ('blighted_agent', 35), ('blossoming_defense', 34), ('noble_hierarch', 33)]
# Cluster 11: [('cauldron_familiar', 353), ('gilded_goose', 352), ('samwise_gamgee', 352), ('chord_of_calling', 352), ('birthing_ritual', 352), ('young_wolf', 230), ('orcish_bowmasters', 207), ('boseiju_who_endures', 177), ('overgrown_tomb', 177), ('viscera_seer', 170)]
# Cluster 12: [('ugins_labyrinth', 108), ('emrakul_the_aeons_torn', 100), ('through_the_breach', 95), ('kozileks_command', 88), ('eldrazi_temple', 88), ('devourer_of_destiny', 69), ('talisman_of_creativity', 64), ('ulamog_the_defiler', 61), ('nulldrifter', 52), ('stock_up', 49)]
# Cluster 13: [('eldrazi_temple', 184), ('ugins_labyrinth', 184), ('eldrazi_linebreaker', 180), ('kozileks_command', 180), ('cavern_of_souls', 178), ('devourer_of_destiny', 173), ('sowing_mycospawn', 171), ('thought-knot_seer', 165), ('sire_of_seven_deaths', 156), ('glaring_fleshraker', 154)]
# Cluster 14: [('shardless_agent', 204), ('subtlety', 204), ('force_of_negation', 203), ('generous_ent', 202), ('endurance', 201), ('street_wraith', 200), ('curator_of_mysteries', 168), ('living_end', 155), ('ardent_plea', 130), ('sink_into_stupor', 93)]
# Cluster 15: [('delighted_halfling', 366), ('agathas_soul_cauldron', 356), ('young_wolf', 354), ('malevolent_rumble', 342), ('walking_ballista', 286), ('grist_the_hunger_tide', 249), ('yawgmoth_thran_physician', 249), ('overgrown_tomb', 203), ('dredgers_insight', 196), ('spymasters_vault', 187)]
# Cluster 16: [('kozileks_command', 952), ('ugins_labyrinth', 952), ('malevolent_rumble', 951), ('eldrazi_temple', 951), ('sowing_mycospawn', 944), ('utopia_sprawl', 935), ('talisman_of_impulse', 837), ('emrakul_the_promised_end', 700), ('icetill_explorer', 548), ('devourer_of_destiny', 530)]
# Cluster 17: [('path_to_exile', 63), ('white_orchid_phantom', 62), ('solitude', 60), ('reprieve', 55), ('field_of_ruin', 51), ('wrath_of_the_skies', 46), ('demolition_field', 43), ('march_of_otherworldly_light', 37), ('sunken_citadel', 35), ('cleansing_wildfire', 27)]
# Cluster 18: [('street_wraith', 144), ('hollow_one', 136), ('faithless_looting', 136), ('burning_inquiry', 134), ('detectives_phoenix', 133), ('marauding_mako', 128), ('goblin_lore', 77), ('arena_of_glory', 77), ('vengevine', 76), ('blazing_rootwalla', 72)]
# Cluster 19: [('basking_broodscale', 724), ('glaring_fleshraker', 724), ('malevolent_rumble', 724), ('kozileks_command', 724), ('eldrazi_temple', 724), ('urzas_saga', 719), ('blade_of_the_bloodchief', 634), ('grove_of_the_burnwillows', 625), ('ancient_stirrings', 622), ('emrakul_the_promised_end', 492)]
# Cluster 20: [('kozileks_command', 1736), ('urzas_mine', 1736), ('urzas_tower', 1736), ('ugins_labyrinth', 1734), ('karn_the_great_creator', 1733), ('urzas_power_plant', 1731), ('expedition_map', 1718), ('eldrazi_temple', 1698), ('devourer_of_destiny', 1663), ('ugin_eye_of_the_storms', 1492)]
# Cluster 21: [('mishras_bauble', 284), ('mox_opal', 284), ('emry_lurker_of_the_loch', 280), ('tamiyo_inquisitive_student', 278), ('mox_amber', 234), ('urzas_saga', 231), ('repeal', 218), ('cori-steel_cutter', 209), ('metallic_rebuke', 183), ('steam_vents', 133)]
# Cluster 22: [('tarmogoyf', 74), ('thoughtseize', 74), ('urzas_saga', 59), ('fatal_push', 58), ('wrenn_and_six', 45), ('ragavan_nimble_pilferer', 44), ('inquisition_of_kozilek', 40), ('lightning_bolt', 30), ('nethergoyf', 28), ('overgrown_tomb', 28)]
# Cluster 23: [('boggart_trawler', 597), ('soul_spike', 100), ('necrodominance', 96), ('thoughtseize', 88), ('fatal_push', 80), ('sheoldred_the_apocalypse', 74), ('fell_the_profane', 74), ('march_of_wretched_sorrow', 72), ('orcish_bowmasters', 69), ('psychic_frog', 48)]
# Cluster 24: [('shardless_agent', 100), ('solitude', 100), ('birthing_ritual', 100), ('omnath_locus_of_creation', 99), ('leyline_binding', 96), ('quantum_riddler', 92), ('subtlety', 78), ('magmatic_hellkite', 61), ('witch_enchanter', 31), ('hallowed_fountain', 25)]
# Cluster 25: [('psychic_frog', 268), ('persist', 266), ('archon_of_cruelty', 262), ('fatal_push', 262), ('thoughtseize', 250), ('abhorrent_oculus', 249), ('unearth', 243), ('faithless_looting', 234), ('emperor_of_bones', 215), ('thought_scour', 209)]
# Cluster 26: [('the_underworld_cookbook', 64), ('asmoranomardicadaistinaculdacar', 63), ('ovalchase_daredevil', 61), ('psychic_frog', 48), ('urzas_saga', 36), ('mox_opal', 31), ('monument_to_endurance', 29), ('gilded_goose', 28), ('natures_rhythm', 28), ('quantum_riddler', 25)]
# Cluster 27: [('kappa_cannoneer', 1156), ('pinnacle_emissary', 1156), ('mishras_bauble', 1156), ('mox_opal', 1156), ('urzas_saga', 1156), ('thoughtcast', 1147), ('spirebluff_canal', 964), ('memnite', 957), ('sink_into_stupor', 954), ('engineered_explosives', 849)]
# Cluster 28: [('amulet_of_vigor', 1988), ('urzas_saga', 1988), ('arboreal_grazer', 1986), ('primeval_titan', 1985), ('spelunking', 1983), ('crumbling_vestige', 1833), ('boseiju_who_endures', 1594), ('gruul_turf', 1586), ('simic_growth_chamber', 1552), ('green_suns_zenith', 1319)]
# Cluster 29: [('ice-fang_coatl', 488), ('birthing_ritual', 488), ('sink_into_stupor', 486), ('abhorrent_oculus', 483), ('flare_of_denial', 477), ('coiling_oracle', 476), ('subtlety', 429), ('shardless_agent', 336), ('dismember', 244), ('hedge_maze', 240)]
# Cluster 30: [('solitude', 72), ('quantum_riddler', 67), ('orims_chant', 65), ('galvanic_discharge', 58), ('wrenn_and_six', 55), ('teferi_time_raveler', 54), ('omnath_locus_of_creation', 51), ('ephemerate', 50), ('stock_up', 48), ('eternal_witness', 44)]
# Cluster 31: [('scion_of_draco', 1168), ('territorial_kavu', 1168), ('leyline_of_the_guildpact', 1168), ('lightning_bolt', 1162), ('leyline_binding', 1159), ('ragavan_nimble_pilferer', 1141), ('phlage_titan_of_fires_fury', 1119), ('doorkeeper_thrull', 924), ('consign_to_memory', 663), ('stubborn_denial', 616)]
# Cluster 32: [('solitude', 472), ('ephemerate', 468), ('ocelot_pride', 463), ('guide_of_souls', 461), ('phelia_exuberant_shepherd', 458), ('quantum_riddler', 458), ('witch_enchanter', 445), ('white_orchid_phantom', 414), ('flagstones_of_trokair', 401), ('hallowed_fountain', 387)]
# Cluster 33: [('thundertrap_trainer', 188), ('flame_of_anor', 179), ('snapcaster_mage', 137), ('flare_of_denial', 133), ('counterspell', 124), ('phlage_titan_of_fires_fury', 122), ('tamiyo_inquisitive_student', 116), ('steam_vents', 111), ('lightning_bolt', 100), ('galvanic_discharge', 85)]
# Cluster 34: [('psychic_frog', 626), ('fatal_push', 556), ('counterspell', 552), ('thoughtseize', 494), ('force_of_negation', 444), ('tamiyo_inquisitive_student', 433), ('subtlety', 433), ('watery_grave', 377), ('quantum_riddler', 370), ('orcish_bowmasters', 364)]
# Cluster 35: [('dragons_rage_channeler', 2412), ('slickshot_show-off', 2412), ('lava_dart', 2412), ('lightning_bolt', 2412), ('cori-steel_cutter', 2412), ('mishras_bauble', 2412), ('monastery_swiftspear', 2411), ('preordain', 2411), ('expressive_iteration', 2386), ('mutagenic_growth', 2130)]
# Cluster 36: [('phelia_exuberant_shepherd', 544), ('quantum_riddler', 544), ('overlord_of_the_balemurk', 536), ('fatal_push', 381), ('psychic_frog', 370), ('subtlety', 348), ('solitude', 337), ('force_of_negation', 315), ('ephemerate', 313), ('teferi_time_raveler', 269)]
# Cluster 37: [('quantum_riddler', 1760), ('solitude', 1760), ('phlage_titan_of_fires_fury', 1757), ('consign_to_memory', 1611), ('phelia_exuberant_shepherd', 1457), ('ragavan_nimble_pilferer', 1451), ('teferi_time_raveler', 1074), ('prismatic_ending', 1017), ('fable_of_the_mirror-breaker', 999), ('arena_of_glory', 892)]
# Cluster 38: [('kappa_cannoneer', 128), ('pinnacle_emissary', 128), ('mishras_bauble', 128), ('mox_opal', 128), ('urzas_saga', 128), ('spirebluff_canal', 126), ('weapons_manufacturing', 125), ('memnite', 123), ('springleaf_drum', 117), ('arcbound_ravager', 115)]
# Cluster 39: [('narset_parter_of_veils', 364), ('solitude', 364), ('orims_chant', 361), ('teferi_time_raveler', 305), ('prismatic_ending', 274), ('consult_the_star_charts', 226), ('counterspell', 221), ('hallowed_fountain', 193), ('meticulous_archive', 177), ('force_of_negation', 176)]
# Cluster 40: [('atraxa_grand_unifier', 1008), ('psychic_frog', 1008), ('solitude', 1008), ('ephemerate', 1008), ('goryos_vengeance', 1008), ('quantum_riddler', 1007), ('faithful_mending', 908), ('force_of_negation', 771), ('thoughtseize', 703), ('prismatic_ending', 654)]
# Cluster 41: [('ajani_nacatl_pariah', 1760), ('guide_of_souls', 1760), ('ocelot_pride', 1760), ('ragavan_nimble_pilferer', 1760), ('galvanic_discharge', 1760), ('phlage_titan_of_fires_fury', 1750), ('seasoned_pyromancer', 1467), ('sacred_foundry', 1335), ('goblin_bombardment', 1320), ('arena_of_glory', 1313)]

# %% [markdown]
# ## Map clusters to archetypes

# %%
cluster_mapping = {
    0: "R Belcher",
    1: "Other",
    2: "U Belcher",
    3: "RW Burn",
    4: "UB Mill",
    5: "R Storm",
    6: "UG Neoform",
    7: "Dredge",
    8: "Hammertime",
    9: "Merfolk",
    10: "Infect",
    11: "Samwise Combo",
    12: "UR Breach",
    13: "Eldrazi Aggro",
    14: "Living End",
    15: "Yawgmoth",
    16: "RG Eldrazi",
    17: "Wx Ponza",
    18: "Hollow One",
    19: "Broodscale Combo",
    20: "Eldrazi Tron",
    21: "UR Mox Cutter",
    22: "Jund Saga",
    23: "B Necro",
    24: "4-Color Ritual",
    25: "Reanimator",
    26: "Asmo Food",
    27: "Affinity",
    28: "Amulet Titan",
    29: "UG Ritual",
    30: "4-Color Control",
    31: "Domain Zoo",
    32: "UW Energy",
    33: "Jeskai Wizards",
    34: "UB Frog",
    35: "UR Prowess",
    36: "Esper Blink",
    37: "Jeskai Blink",
    38: "Affnity",
    39: "UW Control",
    40: "Esper Goryo's",
    41: "RW Energy",
}

df_train['archetype'] = df_train['merged_cluster'].map(lambda x: cluster_mapping.get(x, "Other"))

# %% [markdown]
# ## Train Classifier & Predict on Test Set

# %%
mask = df_train["cluster"] != -1
X_train_masked = X_train_reduced[mask]
y_train_masked = df_train.loc[mask, "archetype"]

clf = LogisticRegression(max_iter=500)
clf.fit(X_train_masked, y_train_masked)

# Predict archetypes for test set
df_test['archetype'] = clf.predict(X_test_reduced)
df_test['confidence'] = clf.predict_proba(X_test_reduced).max(axis=1)

# %% [markdown]
# ## Metrics/Visualizations Generation

# %%
# ----------------------------
# Archetype Metrics
# ----------------------------
archetype_counts = df_train['archetype'].value_counts()
print("Number of decks per archetype:\n", archetype_counts)

# ----------------------------
# Test Set Confidence
# ----------------------------
mean_confidence = df_test['confidence'].mean() * 100
mean_conf_per_archetype = df_test.groupby('archetype')['confidence'].mean() * 100
print(f"Mean classifier confidence on test set: {mean_confidence:.2f}%")
print("Mean confidence per predicted archetype (test set):\n", mean_conf_per_archetype)

# ----------------------------
# Charts
# ----------------------------

# 1. Number of decks per archetype (train)
plt.figure(figsize=(12,6))
archetype_counts.plot(kind='bar')
plt.title("Number of Decks per Archetype (Train Set)")
plt.xlabel("Archetype")
plt.ylabel("Number of Decks")
plt.tight_layout()
plt.savefig("archetype_counts.png")
plt.close()

# 2. Confidence distribution by archetype (test set)
median_conf = df_test.groupby('archetype')['confidence'].median().sort_values(ascending=True)
sorted_archetypes = median_conf.index.tolist()
data_to_plot = [df_test[df_test['archetype'] == archetype]['confidence'] 
                for archetype in sorted_archetypes]
plt.figure(figsize=(10, 12))
box = plt.boxplot(data_to_plot, vert=False, labels=sorted_archetypes, patch_artist=True)
for i, line in enumerate(box['medians']):
    x, y = line.get_xdata()[1], line.get_ydata()[1]
    plt.text(x-0.02, y + 0.17, f"{x:.2f}", va='center', fontsize=9, color='black')
plt.boxplot(data_to_plot, vert=False, labels=sorted_archetypes)
plt.xlabel("Confidence")
plt.ylabel("Predicted Archetype")
plt.title("Classifier Confidence by Predicted Archetype (Test Set)")
plt.tight_layout()
plt.savefig("confidence_by_archetype_test.png")
plt.close()
# Out:
# Number of decks per archetype:
#  archetype
# Other               4396
# UR Prowess           603
# Amulet Titan         497
# RW Energy            440
# Jeskai Blink         440
# Eldrazi Tron         434
# Domain Zoo           292
# Affinity             289
# Esper Goryo's        252
# RG Eldrazi           238
# U Belcher            237
# Broodscale Combo     181
# R Storm              175
# UB Frog              157
# Esper Blink          137
# UG Ritual            122
# UW Energy            118
# UB Mill              107
# Yawgmoth              92
# UW Control            91
# Samwise Combo         89
# UR Mox Cutter         71
# Reanimator            67
# Jeskai Wizards        60
# Living End            51
# UG Neoform            50
# Eldrazi Aggro         46
# Merfolk               42
# Hollow One            36
# RW Burn               33
# Affnity               32
# Dredge                30
# UR Breach             27
# Hammertime            26
# B Necro               26
# 4-Color Ritual        25
# Infect                24
# R Belcher             23
# Jund Saga             20
# 4-Color Control       18
# Wx Ponza              16
# Asmo Food             16
# Name: count, dtype: int64
# Mean classifier confidence on test set: 91.18%
# Mean confidence per predicted archetype (test set):
#  archetype
# 4-Color Control     33.682585
# 4-Color Ritual      74.725056
# Affinity            86.357366
# Affnity             60.701122
# Amulet Titan        97.328436
# Asmo Food           59.108152
# B Necro             66.196017
# Broodscale Combo    95.571902
# Domain Zoo          96.627242
# Dredge              80.922398
# Eldrazi Aggro       79.275235
# Eldrazi Tron        96.582169
# Esper Blink         86.235659
# Esper Goryo's       94.354713
# Hammertime          78.145073
# Hollow One          84.131176
# Jeskai Blink        93.981024
# Jeskai Wizards      70.500382
# Jund Saga           40.251759
# Living End          81.769778
# Merfolk             78.462492
# Other               26.630610
# R Belcher           76.221386
# R Storm             95.997128
# RG Eldrazi          95.441846
# RW Burn             64.587408
# RW Energy           97.071930
# Reanimator          65.949276
# Samwise Combo       89.247840
# U Belcher           96.503340
# UB Frog             85.197029
# UB Mill             92.725046
# UG Neoform          84.234149
# UG Ritual           93.900315
# UR Breach           76.582561
# UR Mox Cutter       76.694750
# UR Prowess          96.562433
# UW Control          84.643763
# UW Energy           77.306708
# Wx Ponza            64.925577
# Yawgmoth            90.527071
# Name: confidence, dtype: float64
